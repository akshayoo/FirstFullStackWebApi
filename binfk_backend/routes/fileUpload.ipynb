# %%
import pandas as pd

# %%
data = pd.read_csv("template.ncounter.csv")

# %%
data.head()
# Out:
#   Sample ID               Description  RNA Conc.                      Notes  \
# 0      S009     Tumor tissue – breast      267.4                High purity
# 1      S010     Tumor tissue – breast      254.1          Minor degradation
# 2      S011     Tumor tissue – breast      279.6            Excellent yield
# 3      S012  Adjacent normal – breast      198.5                        NaN
# 4      S013  Adjacent normal – breast      187.9  Slight salt contamination
#
#   Replicate(Group Name)
# 0          Rep1 (Tumor)
# 1          Rep2 (Tumor)
# 2          Rep3 (Tumor)
# 3         Rep1 (Normal)
# 4         Rep2 (Normal)

# %%
ecords = data.fillna("No Value").to_dict(orient="records")

# %%
ecords
# Out:
# [{'Sample ID': 'S009',
#   'Description': 'Tumor tissue – breast',
#   'RNA Conc.': 267.4,
#   'Notes': 'High purity',
#   'Replicate(Group Name)': 'Rep1 (Tumor)'},
#  {'Sample ID': 'S010',
#   'Description': 'Tumor tissue – breast',
#   'RNA Conc.': 254.1,
#   'Notes': 'Minor degradation',
#   'Replicate(Group Name)': 'Rep2 (Tumor)'},
#  {'Sample ID': 'S011',
#   'Description': 'Tumor tissue – breast',
#   'RNA Conc.': 279.6,
#   'Notes': 'Excellent yield',
#   'Replicate(Group Name)': 'Rep3 (Tumor)'},
#  {'Sample ID': 'S012',
#   'Description': 'Adjacent normal – breast',
#   'RNA Conc.': 198.5,
#   'Notes': 'No Value',
#   'Replicate(Group Name)': 'Rep1 (Normal)'},
#  {'Sample ID': 'S013',
#   'Description': 'Adjacent normal – breast',
#   'RNA Conc.': 187.9,
#   'Notes': 'Slight salt contamination',
#   'Replicate(Group Name)': 'Rep2 (Normal)'},
#  {'Sample ID': 'S014',
#   'Description': 'Adjacent normal – breast',
#   'RNA Conc.': 205.3,
#   'Notes': 'Sequencing ready',
#   'Replicate(Group Name)': 'Rep3 (Normal)'},
#  {'Sample ID': 'S015',
#   'Description': 'Tumor tissue – colon',
#   'RNA Conc.': 221.7,
#   'Notes': 'No Value',
#   'Replicate(Group Name)': 'Rep1 (Tumor)'},
#  {'Sample ID': 'S016',
#   'Description': 'Tumor tissue – colon',
#   'RNA Conc.': 239.2,
#   'Notes': 'Good integrity',
#   'Replicate(Group Name)': 'Rep2 (Tumor)'},
#  {'Sample ID': 'S017',
#   'Description': 'Tumor tissue – colon',
#   'RNA Conc.': 226.8,
#   'Notes': 'Suitable for library prep',
#   'Replicate(Group Name)': 'Rep3 (Tumor)'},
#  {'Sample ID': 'S018',
#   'Description': 'Adjacent normal – colon',
#   'RNA Conc.': 171.4,
#   'Notes': 'No Value',
#   'Replicate(Group Name)': 'Rep1 (Normal)'},
#  {'Sample ID': 'S019',
#   'Description': 'Adjacent normal – colon',
#   'RNA Conc.': 184.6,
#   'Notes': 'Acceptable quality',
#   'Replicate(Group Name)': 'Rep2 (Normal)'},
#  {'Sample ID': 'S020',
#   'Description': 'Adjacent normal – colon',
#   'RNA Conc.': 193.9,
#   'Notes': 'Stable RNA',
#   'Replicate(Group Name)': 'Rep3 (Normal)'},
#  {'Sample ID': 'S021',
#   'Description': 'Cell line – treated',
#   'RNA Conc.': 312.8,
#   'Notes': 'No Value',
#   'Replicate(Group Name)': 'Rep1 (Treated)'},
#  {'Sample ID': 'S022',
#   'Description': 'Cell line – treated',
#   'RNA Conc.': 305.1,
#   'Notes': 'Slight foaming observed',
#   'Replicate(Group Name)': 'Rep2 (Treated)'},
#  {'Sample ID': 'S023',
#   'Description': 'Cell line – treated',
#   'RNA Conc.': 297.6,
#   'Notes': 'Consistent yield',
#   'Replicate(Group Name)': 'Rep3 (Treated)'},
#  {'Sample ID': 'S024',
#   'Description': 'Cell line – untreated',
#   'RNA Conc.': 289.4,
#   'Notes': 'Control baseline',
#   'Replicate(Group Name)': 'Rep1 (Control)'},
#  {'Sample ID': 'S025',
#   'Description': 'Cell line – untreated',
#   'RNA Conc.': 276.2,
#   'Notes': 'Mild degradation',
#   'Replicate(Group Name)': 'Rep2 (Control)'},
#  {'Sample ID': 'S026',
#   'Description': 'Cell line – untreated',
#   'RNA Conc.': 283.7,
#   'Notes': 'Good for downstream analysis',
#   'Replicate(Group Name)': 'Rep3 (Control)'}]

# %%
sample_id = list(data["Sample ID"].fillna("No Value").values)
description = list(data["Description"].fillna("No Value").values)
rna_conc = list(data["RNA Conc."].fillna("No Value").values)
notes = list(data["Notes"].fillna("No Value").values)
repl_groupname = list(data["Replicate(Group Name)"].fillna("No Value").values)

# %%
sample_id
# Out:
# ['S009',
#  'S010',
#  'S011',
#  'S012',
#  'S013',
#  'S014',
#  'S015',
#  'S016',
#  'S017',
#  'S018',
#  'S019',
#  'S020',
#  'S021',
#  'S022',
#  'S023',
#  'S024',
#  'S025',
#  'S026']

# %%
notes
# Out:
# ['High purity',
#  'Minor degradation',
#  'Excellent yield',
#  'No Value',
#  'Slight salt contamination',
#  'Sequencing ready',
#  'No Value',
#  'Good integrity',
#  'Suitable for library prep',
#  'No Value',
#  'Acceptable quality',
#  'Stable RNA',
#  'No Value',
#  'Slight foaming observed',
#  'Consistent yield',
#  'Control baseline',
#  'Mild degradation',
#  'Good for downstream analysis']
